# %% [markdown]
# # Plotting Wind Direction Using Quiver
#
# This example demonstrates using quiver to plot wind speed contours and wind
# direction arrows from wind vector component input data. The vector components
# are co-located in space in this case.
#
# For the second plot, the data used for the arrows is normalised to produce
# arrows with a uniform size on the plot.

# %%
import cartopy.feature as cfeat
import matplotlib.pyplot as plt

import iris
import iris.plot as iplt
import iris.quickplot as qplt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cartopy.feature as cfeat
#       2 import matplotlib.pyplot as plt
#       4 import iris
#
# ModuleNotFoundError: No module named 'cartopy'

# %%
# !pip install cartopy
# Out:
# Collecting cartopy
#   Downloading Cartopy-0.21.1.tar.gz (10.9 MB)
#      |████████████████████████████████| 10.9 MB 232 kB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: matplotlib>=3.1 in /opt/anaconda3/lib/python3.9/site-packages (from cartopy) (3.5.1)
# Collecting pyshp>=2.1
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 2.5 MB/s eta 0:00:01
# Collecting shapely>=1.6.4
#   Using cached shapely-2.0.1-cp39-cp39-macosx_10_9_x86_64.whl (1.4 MB)
# Requirement already satisfied: numpy>=1.18 in /opt/anaconda3/lib/python3.9/site-packages (from cartopy) (1.21.5)
# Collecting pyproj>=3.0.0
#   Downloading pyproj-3.5.0-cp39-cp39-macosx_10_9_x86_64.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 492 kB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->cartopy) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->cartopy) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->cartopy) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->cartopy) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->cartopy) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->cartopy) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->cartopy) (9.0.1)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from pyproj>=3.0.0->cartopy) (2021.10.8)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.1->cartopy) (1.16.0)
# Building wheels for collected packages: cartopy
#   Building wheel for cartopy (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/anaconda3/bin/python /opt/anaconda3/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/_in_process.py build_wheel /var/folders/_8/stsrqpjs1q1559jp3dtpqv0c0000gn/T/tmpfgf1qze4
#        cwd: /private/var/folders/_8/stsrqpjs1q1559jp3dtpqv0c0000gn/T/pip-install-o0ya65cs/cartopy_dd7191cec07e45cc90515165b5c9c697
#   Complete output (287 lines):
#   <string>:90: UserWarning: Unable to determine GEOS version. Ensure you have 3.7.2 or later installed, or installation may fail.
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-cpython-39
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy
#   copying lib/cartopy/geodesic.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy
#   copying lib/cartopy/_version.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy
#   copying lib/cartopy/_epsg.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy
#   copying lib/cartopy/util.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy
#   copying lib/cartopy/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy
#   copying lib/cartopy/crs.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy
#   copying lib/cartopy/img_transform.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy
#   copying lib/cartopy/vector_transform.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/io
#   copying lib/cartopy/io/img_tiles.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/io
#   copying lib/cartopy/io/shapereader.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/io
#   copying lib/cartopy/io/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/io
#   copying lib/cartopy/io/img_nest.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/io
#   copying lib/cartopy/io/srtm.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/io
#   copying lib/cartopy/io/ogc_clients.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/io
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/conftest.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_features.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_coding_standards.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_img_nest.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_coastline.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_geodesic.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_shapereader.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_vector_transform.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_line_string.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_util.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_crs_transform_vectors.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_polygon.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_linear_ring.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_img_tiles.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_img_transform.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   copying lib/cartopy/tests/test_crs.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/patch.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/slippy_image_artist.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/style.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/feature_artist.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/clip_path.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/geoaxes.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/geocollection.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/ticker.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/contour.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   copying lib/cartopy/mpl/gridliner.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/mpl
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/feature
#   copying lib/cartopy/feature/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/feature
#   copying lib/cartopy/feature/nightshade.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/feature
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/io
#   copying lib/cartopy/tests/io/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/io
#   copying lib/cartopy/tests/io/test_downloaders.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/io
#   copying lib/cartopy/tests/io/test_ogc_clients.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/io
#   copying lib/cartopy/tests/io/test_srtm.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/io
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/conftest.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_plots.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_features.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_images.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_set_extent.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_nightshade.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_shapely_to_mpl.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_gridliner.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_ticker.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_patch.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_quiver.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_style.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_img_transform.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_web_services.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_caching.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_crs.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_contour.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_ticks.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_axes.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_pseudo_color.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_examples.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_feature_artist.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   copying lib/cartopy/tests/mpl/test_mpl_integration.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/feature
#   copying lib/cartopy/tests/feature/test_nightshade.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/feature
#   copying lib/cartopy/tests/feature/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/feature
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_orthographic.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_eckert.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_robinson.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_mercator.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_rotated_geodetic.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_geostationary.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_rotated_pole.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_sinusoidal.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_equidistant_conic.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_nearside_perspective.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_miller.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_mollweide.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_interrupted_goode_homolosine.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_lambert_conformal.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_lambert_azimuthal_equal_area.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_transverse_mercator.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_equal_earth.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_utm.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_albers_equal_area.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/helpers.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_azimuthal_equidistant.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_gnomonic.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   copying lib/cartopy/tests/crs/test_stereographic.py -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/crs
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_ticks/xticks_no_transform.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_ticks/yticks_cylindrical.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_ticks/xyticks.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_ticks/yticks_no_transform.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_ticks/xticks_cylindrical.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_ticks
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_images
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_images/imshow_natural_earth_ortho.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_images
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_images/image_nest.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_images
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_images/image_merge.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_images
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_images/web_tiles.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_images
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_images/imshow_regional_projected.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_images
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_web_services
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_web_services/wms.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_web_services
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_web_services/wmts.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_web_services
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_PlateCarree.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_Orthographic.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_InterruptedGoodeHomolosine.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_NorthPolarStereo.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_LambertConformal.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_RotatedPole.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_Sinusoidal.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_LambertAzimuthalEqualArea.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_Mollweide.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_OSGB.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_LambertCylindrical.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_AlbersEqualArea.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/gridliner_labels_tight.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_RotatedPole.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_SouthPolarStereo.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_NearsidePerspective.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_OSNI.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/gridliner_labels.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_Mollweide.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/gridliner1.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_PlateCarree.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/gridliner_labels_bbox_style.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_EuroPP.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_LambertCylindrical.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_AzimuthalEquidistant.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_Geostationary.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_Mercator.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_Stereographic.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_Orthographic.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_Mercator.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_LambertAzimuthalEqualArea.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_SouthPolarStereo.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_AzimuthalEquidistant.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_Sinusoidal.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_Geostationary.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_LambertConformal.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_NorthPolarStereo.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_Miller.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_AlbersEqualArea.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_NearsidePerspective.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_Miller.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_Stereographic.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_Gnomonic.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_Gnomonic.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_InterruptedGoodeHomolosine.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_Robinson.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_gridliner/test_grid_labels_inline_usa_Robinson.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_gridliner
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_img_transform
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_img_transform/regrid_image.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_img_transform
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_shapely_to_mpl
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_shapely_to_mpl/poly_interiors.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_shapely_to_mpl
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_shapely_to_mpl/contour_with_interiors.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_shapely_to_mpl
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_examples
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_examples/contour_label.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_examples
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_examples/global_map.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_examples
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_nightshade
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_nightshade/nightshade_platecarree.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_nightshade
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_img_tiles2
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_img_tiles2/web_tiles.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_img_tiles2
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_axes
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_axes/geoaxes_set_boundary_clipping.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_axes
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_axes/geoaxes_subslice.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_axes
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_crs
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_crs/igh_ocean.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_crs
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_crs/lambert_conformal_south.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_crs
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_crs/igh_land.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_crs
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_features
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_features/natural_earth_custom.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_features
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_features/gshhs_coastlines.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_features
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_features/wfs.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_features
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_features/natural_earth.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_features
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_goode_wrap.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/quiver_rotated_pole.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_InterruptedGoodeHomolosine.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_RotatedPole.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/quiver_plate_carree.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_Orthographic.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_OSGB.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_NorthPolarStereo.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_PlateCarree.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_EckertII.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/barbs_1d.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/barbs_1d_transformed.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_global_wrap1.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_global_wrap2.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_Mollweide.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_global_wrap3.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_EckertIII.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_EckertI.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_SouthPolarStereo.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_annotate.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_hexbin_wrap.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_Miller.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/barbs_plate_carree.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_EckertVI.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_contour_wrap.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_limited_area_wrap.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_single_column_wrap.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_EckertV.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/barbs_regrid.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/quiver_regrid_with_extent.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_Stereographic.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_Mercator.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/pcolormesh_mercator_wrap.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_TransverseMercator.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_Robinson.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_scatter_wrap.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/streamplot.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_EqualEarth.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_contourf_wrap.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/quiver_regrid.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_Gnomonic.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/global_pcolor_wrap.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/simple_global.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/barbs_regrid_with_extent.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_EckertIV.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   copying lib/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration/test_global_map_LambertCylindrical.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/mpl/baseline_images/mpl/test_mpl_integration
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/raster
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/raster/natural_earth
#   copying lib/cartopy/data/raster/natural_earth/images.json -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/raster/natural_earth
#   copying lib/cartopy/data/raster/natural_earth/50-natural-earth-1-downsampled.png -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/raster/natural_earth
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/raster/sample
#   copying lib/cartopy/data/raster/sample/Miriam.A2012270.2050.2km.jpg -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/raster/sample
#   copying lib/cartopy/data/raster/sample/Miriam.A2012270.2050.2km.README.txt -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/raster/sample
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/netcdf
#   copying lib/cartopy/data/netcdf/HadISST1_SST_update.README.txt -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/netcdf
#   copying lib/cartopy/data/netcdf/HadISST1_SST_update.nc -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/netcdf
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles/gshhs
#   copying lib/cartopy/data/shapefiles/gshhs/README.TXT -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles/gshhs
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles/gshhs/c
#   copying lib/cartopy/data/shapefiles/gshhs/c/GSHHS_c_L1.dbf -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles/gshhs/c
#   copying lib/cartopy/data/shapefiles/gshhs/c/GSHHS_c_L1.shx -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles/gshhs/c
#   copying lib/cartopy/data/shapefiles/gshhs/c/GSHHS_c_L1.shp -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles/gshhs/c
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles/gshhs/l
#   copying lib/cartopy/data/shapefiles/gshhs/l/GSHHS_l_L2.dbf -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles/gshhs/l
#   copying lib/cartopy/data/shapefiles/gshhs/l/GSHHS_l_L2.shp -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles/gshhs/l
#   copying lib/cartopy/data/shapefiles/gshhs/l/GSHHS_l_L2.shx -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/data/shapefiles/gshhs/l
#   creating build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/lakes_shapefile
#   copying lib/cartopy/tests/lakes_shapefile/ne_110m_lakes.dbf -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/lakes_shapefile
#   copying lib/cartopy/tests/lakes_shapefile/ne_110m_lakes.shp -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/lakes_shapefile
#   copying lib/cartopy/tests/lakes_shapefile/ne_110m_lakes.shx -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/tests/lakes_shapefile
#   copying lib/cartopy/io/srtm.npz -> build/lib.macosx-10.9-x86_64-cpython-39/cartopy/io
#   running build_ext
#   building 'cartopy.trace' extension
#   creating build/temp.macosx-10.9-x86_64-cpython-39
#   creating build/temp.macosx-10.9-x86_64-cpython-39/lib
#   creating build/temp.macosx-10.9-x86_64-cpython-39/lib/cartopy
#   clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include -fPIC -O2 -isystem /opt/anaconda3/include -arch x86_64 -I/opt/anaconda3/include -I./lib/cartopy -I/private/var/folders/_8/stsrqpjs1q1559jp3dtpqv0c0000gn/T/pip-build-env-u5muqwjf/overlay/lib/python3.9/site-packages/numpy/core/include -I/opt/anaconda3/include/python3.9 -c lib/cartopy/trace.cpp -o build/temp.macosx-10.9-x86_64-cpython-39/lib/cartopy/trace.o
#   lib/cartopy/trace.cpp:767:10: fatal error: 'geos_c.h' file not found
#   #include "geos_c.h"
#            ^~~~~~~~~~
#   1 error generated.
#   error: command '/usr/bin/clang' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for cartopy
# Failed to build cartopy
# ERROR: Could not build wheels for cartopy which use PEP 517 and cannot be installed directly

# %%
def main():
    # Load the u and v components of wind from a pp file.
    infile = iris.sample_data_path("wind.grib")

    uwind = iris.load_cube(infile, "x_wind")
    vwind = iris.load_cube(infile, "y_wind")

    # Create a cube containing the wind speed.
    windspeed = (uwind**2 + vwind**2) ** 0.5
    windspeed.rename("windspeed")

    # Plot the wind speed as a contour plot.
    qplt.contourf(windspeed, 20)

    # Show the lake on the current axes.
    lakes = cfeat.NaturalEarthFeature(
        "physical", "lakes", "50m", facecolor="none"
    )
    plt.gca().add_feature(lakes)

    # Add arrows to show the wind vectors.
    iplt.quiver(uwind, vwind, pivot="middle")

    plt.title("Wind speed over Lake Victoria")
    qplt.show()

    # Normalise the data for uniform arrow size.
    u_norm = uwind / windspeed
    v_norm = vwind / windspeed

    # Make a new figure for the normalised plot.
    plt.figure()

    qplt.contourf(windspeed, 20)
    plt.gca().add_feature(lakes)
    iplt.quiver(u_norm, v_norm, pivot="middle")

    plt.title("Wind speed over Lake Victoria")
    qplt.show()


if __name__ == "__main__":
    main()
